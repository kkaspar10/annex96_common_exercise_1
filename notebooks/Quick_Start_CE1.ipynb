# %% [markdown]
# # Annex 96 Common Exercise 1 – Quick Start Notebook
#
# This notebook provides a minimal end-to-end setup for:
#
# 1. Installing `CityLearn==2.5.0`
# 2. Cloning the CE1 GitHub repository
# 3. Understanding the TX & VT datasets
# 4. Visualizing the daily reference district load
# 5. Running a simple baseline battery RBC controller
# 6. Evaluating KPIs
#
# If you run into issues, please reach out on the Annex 96 Slack (Common Exercise channel).

# %% [markdown]
# ## 1. Install CityLearn

# %%
# !pip install "CityLearn==2.5.0"
# Out:
# Requirement already satisfied: CityLearn==2.5.0 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (2.5.0)
# Requirement already satisfied: doe_xstock>=1.1.0 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from CityLearn==2.5.0) (1.2.0)
# Requirement already satisfied: gymnasium<=0.28.1 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from CityLearn==2.5.0) (0.28.1)
# Requirement already satisfied: nrel-pysam in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from CityLearn==2.5.0) (7.1.0)
# Requirement already satisfied: numpy<2.0.0 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from CityLearn==2.5.0) (1.26.4)
# Requirement already satisfied: pandas in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from CityLearn==2.5.0) (2.3.3)
# Requirement already satisfied: pyyaml in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from CityLearn==2.5.0) (6.0.3)
# Requirement already satisfied: scikit-learn<=1.2.2 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from CityLearn==2.5.0) (1.2.2)
# Requirement already satisfied: simplejson in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from CityLearn==2.5.0) (3.20.2)
# Requirement already satisfied: torch in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from CityLearn==2.5.0) (2.9.1)
# Requirement already satisfied: torchvision in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from CityLearn==2.5.0) (0.24.1)
# Requirement already satisfied: openstudio<=3.3.0 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from CityLearn==2.5.0) (3.3.0)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from gymnasium<=0.28.1->CityLearn==2.5.0) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from gymnasium<=0.28.1->CityLearn==2.5.0) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from gymnasium<=0.28.1->CityLearn==2.5.0) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from gymnasium<=0.28.1->CityLearn==2.5.0) (0.0.4)
# Requirement already satisfied: scipy>=1.3.2 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from scikit-learn<=1.2.2->CityLearn==2.5.0) (1.15.3)
# Requirement already satisfied: joblib>=1.1.1 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from scikit-learn<=1.2.2->CityLearn==2.5.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from scikit-learn<=1.2.2->CityLearn==2.5.0) (3.6.0)
# Requirement already satisfied: beautifulsoup4 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from doe_xstock>=1.1.0->CityLearn==2.5.0) (4.8.0)
# Requirement already satisfied: eppy in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from doe_xstock>=1.1.0->CityLearn==2.5.0) (0.5.63)
# Requirement already satisfied: platformdirs in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from doe_xstock>=1.1.0->CityLearn==2.5.0) (4.5.0)
# Requirement already satisfied: pyarrow in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from doe_xstock>=1.1.0->CityLearn==2.5.0) (22.0.0)
# Requirement already satisfied: requests in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from doe_xstock>=1.1.0->CityLearn==2.5.0) (2.32.5)
# Requirement already satisfied: soupsieve>=1.2 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from beautifulsoup4->doe_xstock>=1.1.0->CityLearn==2.5.0) (2.8)
# Requirement already satisfied: munch>=2.0.2 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from eppy->doe_xstock>=1.1.0->CityLearn==2.5.0) (4.0.0)
# Requirement already satisfied: tinynumpy>=1.2.1 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from eppy->doe_xstock>=1.1.0->CityLearn==2.5.0) (1.2.1)
# Requirement already satisfied: six>=1.10.0 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from eppy->doe_xstock>=1.1.0->CityLearn==2.5.0) (1.17.0)
# Requirement already satisfied: decorator>=4.0.10 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from eppy->doe_xstock>=1.1.0->CityLearn==2.5.0) (5.2.1)
# Requirement already satisfied: lxml>=3.8.0 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from eppy->doe_xstock>=1.1.0->CityLearn==2.5.0) (6.0.2)
# Requirement already satisfied: future in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from eppy->doe_xstock>=1.1.0->CityLearn==2.5.0) (1.0.0)
# Requirement already satisfied: pydot3k in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from eppy->doe_xstock>=1.1.0->CityLearn==2.5.0) (1.0.17)
# Requirement already satisfied: pyparsing>=2.4.7 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from eppy->doe_xstock>=1.1.0->CityLearn==2.5.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from pandas->CityLearn==2.5.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from pandas->CityLearn==2.5.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from pandas->CityLearn==2.5.0) (2025.2)
# Requirement already satisfied: setuptools in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from pydot3k->eppy->doe_xstock>=1.1.0->CityLearn==2.5.0) (80.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from requests->doe_xstock>=1.1.0->CityLearn==2.5.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from requests->doe_xstock>=1.1.0->CityLearn==2.5.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from requests->doe_xstock>=1.1.0->CityLearn==2.5.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from requests->doe_xstock>=1.1.0->CityLearn==2.5.0) (2025.11.12)
# Requirement already satisfied: filelock in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (3.4.2)
# Requirement already satisfied: jinja2 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torch->CityLearn==2.5.0) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from sympy>=1.13.3->torch->CityLearn==2.5.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from jinja2->torch->CityLearn==2.5.0) (3.0.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages (from torchvision->CityLearn==2.5.0) (12.0.0)

# %% [markdown]
# ## 2. Clone the Common Exercise 1 Repository
#
# This repository contains:
#
# - Pre-configured scenarios for **Texas (TX)** and **Vermont (VT)**
# - The `schema_clean.json` files for the 25 homes
# - Pre-computed reference district load profiles
# - Example notebooks (including this Quick Start)
#
# > Replace the placeholder URL with the actual CE1 GitHub link.

# %% [markdown]
# ## 3. Dataset Overview (TX vs VT)
#
# The Common Exercise uses two scenarios:
#
# ### 🔵 Texas (TX) – cooling dominated
# - Training: **August**
# - Testing: **September**
# - Higher solar generation, strong cooling loads.
#
# ### 🔵 Vermont (VT) – heating dominated
# - Training: **January**
# - Testing: **February**
# - High heating loads, low PV in winter.
#
# Each climate folder contains:
#
# - `schema.json`
# - 25 ResStock buildings
# - Pre-computed district reference load
# - All data handled automatically by CityLearn

# %%
from pathlib import Path
import os

# Where the notebook actually lives
NOTEBOOK_DIR = Path(os.getcwd())
print("Notebook directory:", NOTEBOOK_DIR)

# Go one level up to the repo root
BASE_DIR = NOTEBOOK_DIR.parent
print("Repository root:", BASE_DIR)

# Choose climate: TX or VT
CLIMATE = "VT"  # or "VT"

DATASET_DIR = BASE_DIR / "data" / "datasets" / f"annex96_ce1_{CLIMATE.lower()}_neighborhood"
SCHEMA_PATH = DATASET_DIR / "schema.json"

print("\nClimate:", CLIMATE)
print("Dataset directory:", DATASET_DIR, " | exists:", DATASET_DIR.exists())
print("Schema path:", SCHEMA_PATH, " | exists:", SCHEMA_PATH.exists())
# Out:
# Notebook directory: /home/ava_mohammadi/PhD/annex96_ce1/annex96_common_exercise_1/notebooks
# Repository root: /home/ava_mohammadi/PhD/annex96_ce1/annex96_common_exercise_1
#
# Climate: VT
# Dataset directory: /home/ava_mohammadi/PhD/annex96_ce1/annex96_common_exercise_1/data/datasets/annex96_ce1_vt_neighborhood  | exists: True
# Schema path: /home/ava_mohammadi/PhD/annex96_ce1/annex96_common_exercise_1/data/datasets/annex96_ce1_vt_neighborhood/schema.json  | exists: True

# %% [markdown]
# ## 4. Reference District Load
#
# Each day, the Annex 96 CE defines a **constant district load target** equal to the average aggregated demand of all buildings for the next day.
#
# Controllers attempt to track this reference profile.
#
# Below is the reference load plot for the selected climate (TX or VT).

# %% [markdown]
# ## 5. Run a Simple Battery RBC Controller
#
# This baseline:
#
# - Uses the built-in `BasicRBC` controller
# - Controls all buildings through a **central agent**
# - Produces reference KPIs to compare against learning-based methods

# %%
import sys
from pathlib import Path

# Show current paths once (optional, for debugging)
print("Before cleanup:")
for p in sys.path:
    print("  ", p)

# Remove any paths that point to your local dev CityLearn repo
CANDIDATES = ["Occupant_Thermostat_Int", "CityLearn"]

sys.path = [
    p for p in sys.path
    if not any(c in (p or "") for c in CANDIDATES)
]

print("\nAfter cleanup:")
for p in sys.path:
    print("  ", p)
# Out:
# Before cleanup:
#    /home/ava_mohammadi/PhD/CityLearn/Occupant_Thermostat_Int
#    /home/ava_mohammadi/PhD/annex96_ce1/annex96_common_exercise_1/notebooks
#    /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python310.zip
#    /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10
#    /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/lib-dynload
#
#    /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages
#
# After cleanup:
#    /home/ava_mohammadi/PhD/annex96_ce1/annex96_common_exercise_1/notebooks
#    /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python310.zip
#    /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10
#    /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/lib-dynload
#
#    /home/ava_mohammadi/miniconda3/envs/annex96_ce1/lib/python3.10/site-packages

# %%
from pathlib import Path
from citylearn.citylearn import CityLearnEnv

# From your earlier cells:
# NOTEBOOK_DIR = Path(os.getcwd())
# BASE_DIR = NOTEBOOK_DIR.parent
# CLIMATE = "TX" or "VT"

DATASET_DIR = BASE_DIR / "data" / "datasets" / f"annex96_ce1_{CLIMATE.lower()}_neighborhood"
SCHEMA_PATH = DATASET_DIR / "schema.json"

env = CityLearnEnv(
    schema=str(SCHEMA_PATH),
    root_directory=str(DATASET_DIR),
    central_agent=True,
)
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
from citylearn.citylearn import CityLearnEnv

env = CityLearnEnv(
    schema=str(SCHEMA_PATH),
    root_directory=str(DATASET_DIR),
    central_agent=True,  # single agent controlling all buildings
)

observations, info = env.reset()
print("Number of buildings:", len(env.buildings))
print("Action names (first 10):", env.action_names[0][:10])
print("Observation names (first 15):", env.observation_names[0][:15])
# Out:
# Number of buildings: 25
# Action names (first 10): ['heating_device', 'heating_device', 'heating_device', 'heating_device', 'heating_device', 'heating_device', 'heating_device', 'heating_device', 'heating_device', 'heating_device']
# Observation names (first 15): ['month', 'hour', 'outdoor_dry_bulb_temperature', 'direct_solar_irradiance', 'outdoor_dry_bulb_temperature_predicted_1', 'outdoor_dry_bulb_temperature_predicted_2', 'outdoor_dry_bulb_temperature_predicted_3', 'direct_solar_irradiance_predicted_1', 'direct_solar_irradiance_predicted_2', 'direct_solar_irradiance_predicted_3', 'indoor_dry_bulb_temperature', 'non_shiftable_load', 'dhw_demand', 'cooling_demand', 'heating_demand']

# %%
from citylearn.agents.rbc import HourRBC
from citylearn.building import Building

# Get hour indices (typically 1..24)
hours = Building.get_periodic_observation_metadata()['hour']

battery_action_map = {}

for action_name in env.action_names[0]:
    # Battery / electrical storage actions
    if 'electrical_storage' in action_name or 'storage' in action_name:
        battery_action_map[action_name] = {}

        for h in hours:
            if 9 <= h <= 12:
                value = 0.2    # charge 20% of nominal power
            elif 16 <= h <= 19:
                value = -0.2   # discharge 20% of nominal power
            else:
                value = 0.0    # idle

            battery_action_map[action_name][h] = value

    # Keep thermal devices off in this simple demo
    elif action_name in ['cooling_device', 'heating_device', 'cooling_or_heating_device']:
        battery_action_map[action_name] = {h: 0.0 for h in hours}

# Create the simple hourly RBC
battery_rbc = HourRBC(env, action_map=battery_action_map)
print("Battery RBC created.")
# Out:
# Battery RBC created.

# %%
import citylearn
print("citylearn loaded from:", citylearn.__file__)
# Out:
# citylearn loaded from: /home/ava_mohammadi/PhD/annex96_common_exercise_1/citylearn/__init__.py

# %%
import numpy as np

observations, info = env.reset()
rbc_rewards = []

while not env.terminated:
    actions = battery_rbc.predict(observations)
    observations, reward, terminated, truncated, info = env.step(actions)
    rbc_rewards.append(reward)

rbc_district_load = np.array(env.net_electricity_consumption)
print("Episode finished.")
print("Length of RBC district load:", len(rbc_district_load))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 8
#       6 while not env.terminated:
#       7     actions = battery_rbc.predict(observations)
# ----> 8     observations, reward, terminated, truncated, info = env.step(actions)
#       9     rbc_rewards.append(reward)
#      11 rbc_district_load = np.array(env.net_electricity_consumption)
#
# File ~/PhD/annex96_common_exercise_1/citylearn/citylearn.py:1011, in CityLearnEnv.step(self, actions)
#    1009 # Apply actions at current timestep t
#    1010 for building, building_actions in zip(self.buildings, actions):
# -> 1011     building.apply_actions(**building_actions)
#    1013 # Update environment/building variables for timestep t (reflect effects of actions)
#    1014 self.update_variables()
#
# File ~/PhD/annex96_common_exercise_1/citylearn/building.py:2936, in DynamicsBuilding.apply_actions(self, **kwargs)
#    2935 def apply_actions(self, **kwargs):
# -> 2936     super().apply_actions(**kwargs)
#    2937     self._update_dynamics_input()
#    2939     if self.simulate_dynamics:
#
# File ~/PhD/annex96_common_exercise_1/citylearn/building.py:1631, in Building.apply_actions(self, cooling_or_heating_device_action, cooling_device_action, heating_device_action, cooling_storage_action, heating_storage_action, dhw_storage_action, electrical_storage_action, washing_machine_actions, electric_vehicle_storage_actions)
#    1628 func, args = actions[k]
#    1630 try:
# -> 1631     func(*args)
#    1633 except NotImplementedError:
#    1634     pass
#
# File ~/PhD/annex96_common_exercise_1/citylearn/building.py:1703, in Building.update_energy_from_heating_device(self)
#    1700 max_electric_power = self.downward_electrical_flexibility
#    1701 max_device_output = self.heating_device.get_max_output_power(temperature, heating=True, max_electric_power=max_electric_power) \
#    1702     if isinstance(self.heating_device, HeatPump) else self.heating_device.get_max_output_power(max_electric_power=max_electric_power)
# -> 1703 self.___demand_limit_check('heating', demand, max_device_output)
#    1704 device_output = min(demand - storage_output, max_device_output)
#    1705 self.__energy_from_heating_device[self.time_step] = device_output
#
# File ~/PhD/annex96_common_exercise_1/citylearn/building.py:1828, in Building.___demand_limit_check(self, end_use, demand, max_device_output)
#    1825 def ___demand_limit_check(self, end_use: str, demand: float, max_device_output: float):
#    1826     message = f'timestep: {self.time_step}, building: {self.name}, outage: {self.power_outage}, demand: {demand},' \
#    1827         f'output: {max_device_output}, difference: {demand - max_device_output}, check: {demand <= max_device_output},'
# -> 1828     assert self.power_outage or demand <= max_device_output or abs(demand - max_device_output) < TOLERANCE, \
#    1829         f'demand is greater than {end_use}_device max output | {message}'
#
# AssertionError: demand is greater than heating_device max output | timestep: 0, building: resstock-amy2018-2021-release-1-147002, outage: False, demand: 13.940381050109863,output: 11.416627055757761, difference: 2.523753994352102, check: False,

# %% [markdown]
# ## 6. Evaluate Performance (KPIs)
#
# These KPIs will be used for comparison across all CE1 participants.

# %%
kpis = env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value')
kpis

# %% [markdown]
# ## You're all set!
#
# You now have:
#
# - Installed CityLearn v2.5
# - Loaded TX or VT scenario
# - Viewed district reference loads
# - Run a baseline RBC
# - Computed comparison KPIs
#
# If you run into any issue, please reach out in the **Annex 96 Slack**.
#
# Happy experimenting! 🚀
